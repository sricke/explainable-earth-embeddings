# %%
import sys
import argparse
from pathlib import Path

import numpy as np
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm

sys.path.append("../..")

from dataset import GeoTextDataset
from models.location_encoder import LocationEncoder
from models.text_encoder import TextEncoder

GIT10M_DIR = Path("../../../../data/expanded-git-10M")
SPLITS = ["train", "val", "test"]
DEVICE = "cuda"

# %%
dataset = GeoTextDataset(root=GIT10M_DIR, split="train")

# %%
import random

# %%
indices = random.sample(range(len(dataset)), 100)

for i in indices:
    sample = dataset[i]
    print(f"\n--- Sample {i} ---")
    print(sample)
# Out:
# --- Sample 1637730 ---
# (tensor([ 32.4078, -93.8960]), 'large house')
#
# --- Sample 335529 ---
# (tensor([ 31.5458, 120.4761]), 'some brown patches')
#
# --- Sample 637203 ---
# (tensor([52.5730, 13.4143]), 'residential and commercial buildings')
#
# --- Sample 2799454 ---
# (tensor([40.3277, 77.4811]), 'bodies of water')
#
# --- Sample 2792862 ---
# (tensor([19.0881, 72.8970]), 'primarily residential structures')
#
# --- Sample 2541230 ---
# (tensor([ 40.6348, 117.0813]), 'few narrow dirt roads')
#
# --- Sample 2601704 ---
# (tensor([ 39.2759, -94.6733]), 'central area with a swimming pool')
#
# --- Sample 2185029 ---
# (tensor([ 40.8200, -74.1660]), 'residential neighborhood with a grid-like street pattern')
#
# --- Sample 106074 ---
# (tensor([38.1173, 87.2974]), 'valleys')
#
# --- Sample 2129955 ---
# (tensor([48.9847,  2.5571]), 'sac')
#
# --- Sample 339053 ---
# (tensor([ 38.8097, -90.6564]), 'Trees')
#
# --- Sample 3103113 ---
# (tensor([ 25.9975, -97.5037]), 'Each house')
#
# --- Sample 2336223 ---
# (tensor([ 38.1086, -99.0527]), 'other rectangular agricultural plots')
#
# --- Sample 1716666 ---
# (tensor([-37.9204, 145.1019]), 'access to the various areas')
#
# --- Sample 2504223 ---
# (tensor([ 40.0655, 116.5979]), 'round object')
#
# --- Sample 1300934 ---
# (tensor([ 36.1955, 120.5365]), 'no conspicuous buildings')
#
# --- Sample 594763 ---
# (tensor([ 40.2250, -76.8192]), 'small body of turquoise water')
#
# --- Sample 1591785 ---
# (tensor([-3.0966, 29.5354]), 'No clearings')
#
# --- Sample 2905292 ---
# (tensor([51.3581, -0.1895]), 'green spaces around the buildings')
#
# --- Sample 1433 ---
# (tensor([ 42.3585, -83.5304]), 'green spaces')
#
# --- Sample 1599550 ---
# (tensor([52.5655, 13.1314]), 'Some clearings')
#
# --- Sample 1739620 ---
# (tensor([52.5455, 13.5104]), 'residential area with several houses')
#
# --- Sample 1212488 ---
# (tensor([50.2279, 31.3248]), 'lower part')
#
# --- Sample 3474641 ---
# (tensor([50.0254, 12.6782]), 'tree types')
#
# --- Sample 631603 ---
# (tensor([51.8968,  0.9119]), 'urban area')
#
# --- Sample 933537 ---
# (tensor([ 26.6573, 112.1567]), 'some visible agricultural fields and small, dispersed structures or clearings within the forest')
#
# --- Sample 31121 ---
# (tensor([ 30.8975, 109.1656]), 'lower-left portion')
#
# --- Sample 203172 ---
# (tensor([ 32.0407, 120.1245]), 'consistent planting patterns')
#
# --- Sample 2210635 ---
# (tensor([53.3489, -6.2952]), 'parked vehicles')
#
# --- Sample 2808006 ---
# (tensor([52.6764,  0.7581]), 'rural landscape')
#
# --- Sample 2347582 ---
# (tensor([49.7688, 15.8917]), 'grassy fields')
#
# --- Sample 627500 ---
# (tensor([ 42.6329, -83.3725]), 'driveways')
#
# --- Sample 1140726 ---
# (tensor([37.5620, 23.3652]), 'sparse vegetation')
#
# --- Sample 1710907 ---
# (tensor([ 42.2336, -83.2558]), 'driveways')
#
# --- Sample 546580 ---
# (tensor([51.4677,  0.1305]), 'central road')
#
# --- Sample 2513010 ---
# (tensor([ 71.4896, 100.5812]), 'access to individual properties')
#
# --- Sample 1191245 ---
# (tensor([53.2521, -6.1221]), 'Each row')
#
# --- Sample 2935870 ---
# (tensor([52.9619, -1.2524]), 'both the agricultural and residential zones')
#
# --- Sample 2696206 ---
# (tensor([ 37.2566, 116.1255]), 'Straight roads')
#
# --- Sample 315942 ---
# (tensor([ 38.4202, -90.3282]), 'circular cul-de')
#
# --- Sample 1335826 ---
# (tensor([33.9388, 43.9618]), 'arid landscape')
#
# --- Sample 1217857 ---
# (tensor([ 63.3817, 150.9741]), 'natural landscape')
#
# --- Sample 3444320 ---
# (tensor([ 12.6752, 100.9863]), 'large rectangular paved surface')
#
# --- Sample 1872227 ---
# (tensor([-2.1789, 30.1945]), 'green area with dense vegetation')
#
# --- Sample 2814348 ---
# (tensor([ 42.3484, -83.1445]), 'trees')
#
# --- Sample 3108878 ---
# (tensor([ 38.8055, -90.5164]), 'multiple intersections')
#
# --- Sample 3125252 ---
# (tensor([ 42.6329, -82.9028]), 'rectangular blocks')
#
# --- Sample 2114678 ---
# (tensor([ 38.2641, 140.9326]), 'visible parking areas around some buildings')
#
# --- Sample 2403585 ---
# (tensor([ 35.2052, -89.9011]), 'four main buildings, with access roads')
#
# --- Sample 1944540 ---
# (tensor([52.5288, 13.3910]), 'Trees')
#
# --- Sample 2380787 ---
# (tensor([ 33.9229, 100.1102]), 'minimal human interference')
#
# --- Sample 2955159 ---
# (tensor([  47.2941, -107.8418]), 'riverbanks')
#
# --- Sample 3273515 ---
# (tensor([51.6180,  0.3406]), 'rural landscape')
#
# --- Sample 2323710 ---
# (tensor([30.5575, 31.3055]), 'tree plantations')
#
# --- Sample 1264195 ---
# (tensor([29.4587, 77.0966]), 'few areas of dense tree cover')
#
# --- Sample 420881 ---
# (tensor([ 74.0818, 114.2180]), 'tree-lined road')
#
# --- Sample 1995829 ---
# (tensor([55.3370, 38.1940]), 'open fields')
#
# --- Sample 2974026 ---
# (tensor([-1.2674, 30.1190]), 'patches of vegetation')
#
# --- Sample 2864509 ---
# (tensor([52.5597, 13.1163]), 'partially forested area with dense vegetation')
#
# --- Sample 2186142 ---
# (tensor([52.4443, 13.5393]), 'human-made structures')
#
# --- Sample 504118 ---
# (tensor([51.8697,  4.6431]), 'grassy areas')
#
# --- Sample 1718091 ---
# (tensor([31.2081, 44.0717]), 'rocky terrain')
#
# --- Sample 972744 ---
# (tensor([55.6024, 37.9440]), 'thick canopy of trees')
#
# --- Sample 2601800 ---
# (tensor([ 41.5949, -87.2946]), 'residential area with several houses')
#
# --- Sample 1555697 ---
# (tensor([-37.8944, 144.7256]), 'residential area with multiple houses')
#
# --- Sample 941618 ---
# (tensor([29.8406, 31.1971]), 'expanse of barren land')
#
# --- Sample 461318 ---
# (tensor([ 23.1202, 112.8076]), 'large body of water')
#
# --- Sample 2521211 ---
# (tensor([51.4882,  0.1552]), 'few buildings')
#
# --- Sample 2981676 ---
# (tensor([ 40.5441, 116.2697]), 'some barren patches')
#
# --- Sample 37736 ---
# (tensor([80.4684,  4.8820]), 'multiple buildings with dark-colored roofs')
#
# --- Sample 1644474 ---
# (tensor([33.8385, 40.6110]), 'erosion channels')
#
# --- Sample 667353 ---
# (tensor([ 37.3745, 127.0074]), 'dense network of buildings')
#
# --- Sample 1692585 ---
# (tensor([80.2073,  4.3204]), 'residential buildings')
#
# --- Sample 2768472 ---
# (tensor([51.3675, -0.4230]), 'small road')
#
# --- Sample 3277305 ---
# (tensor([ 39.1194, -94.6390]), 'body of water')
#
# --- Sample 1547591 ---
# (tensor([  53.5534, -113.4888]), 'major roadway')
#
# --- Sample 1286182 ---
# (tensor([51.8663,  4.3684]), 'some trees between buildings')
#
# --- Sample 3046107 ---
# (tensor([ 23.1075, 113.9639]), 'vegetation')
#
# --- Sample 1211390 ---
# (tensor([48.6057,  2.3579]), 'large building with a flat roof')
#
# --- Sample 430454 ---
# (tensor([-38.0870, 145.1486]), 'vegetation')
#
# --- Sample 1418884 ---
# (tensor([ 39.0960, -84.6057]), 'housing areas')
#
# --- Sample 873394 ---
# (tensor([ 41.9084, -87.9977]), 'some greenery')
#
# --- Sample 959021 ---
# (tensor([ 45.3319, -75.8290]), 'wooded area')
#
# --- Sample 1285365 ---
# (tensor([55.2259, 37.6529]), 'narrow, winding path')
#
# --- Sample 49308 ---
# (tensor([51.4814, -0.3708]), 'cars')
#
# --- Sample 2211099 ---
# (tensor([ 41.7682, 124.0137]), 'rural landscape')
#
# --- Sample 924571 ---
# (tensor([ 38.8012, -90.3049]), 'some greenery')
#
# --- Sample 1411350 ---
# (tensor([ 43.9928, 125.4858]), 'few vehicles')
#
# --- Sample 2931238 ---
# (tensor([33.9069, 69.8923]), 'dirt road')
#
# --- Sample 1603163 ---
# (tensor([ 38.7819, -90.3804]), 'grassy area with some trees')
#
# --- Sample 2663485 ---
# (tensor([ 73.1477, -99.0610]), 'lower part')
#
# --- Sample 1148533 ---
# (tensor([ 42.4539, -83.2585]), 'suburban residential area with several houses')
#
# --- Sample 2317239 ---
# (tensor([ 22.3907, 113.2169]), 'few more structures')
#
# --- Sample 1546150 ---
# (tensor([57.0967, 10.1555]), 'rectangular agricultural field')
#
# --- Sample 498644 ---
# (tensor([5.1575e+01, 1.5106e-02]), 'various patches of vegetation')
#
# --- Sample 2685279 ---
# (tensor([31.0659, 30.9087]), 'notable feature')
#
# --- Sample 2004147 ---
# (tensor([ 35.5210, 140.0647]), 'storage facilities')
#
# --- Sample 1632735 ---
# (tensor([-2.7675, 29.4543]), 'farmland')
#
# --- Sample 1335398 ---
# (tensor([ 76.2073, 121.3344]), 'agricultural fields')
#
# --- Sample 3490363 ---
# (tensor([51.5532, -0.3323]), 'residential area with several houses')

# %%
import random

N = len(dataset)
subset_size = 10000  # adjust (e.g., 10k–100k depending on speed)

indices = random.sample(range(N), subset_size)

my_lat, my_lon = 27.9881, 86.9250

import math
def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlambda = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    return 2 * R * math.atan2(math.sqrt(a), math.sqrt(1 - a))

best = None
best_dist = float("inf")

for i in indices:
    latlon, text = dataset[i]
    lat, lon = latlon.tolist()

    dist = haversine(lat, lon, my_lat, my_lon)

    if dist < best_dist:
        best_dist = dist
        best = (i, latlon, text)

print(f"Closest (in subsample): {best_dist:.2f} km")
print(best)
# Out:
# Closest (in subsample): 117.52 km
# (648207, tensor([28.3044, 85.7812]), 'ice')
