# %% [markdown]
# # Exploratory Data Analysis on Earth Embeddings and Relevant Variables
#
# ## Variables include Elevation, Biome, Ecoregion, Temperature, Population Density,...

# %% [markdown]
# ### Imports

# %%
import os
import sys
from pathlib import Path

# %%
import torch
import pandas as pd
import numpy as np

# %%
parent = Path.cwd().parent

# %% [markdown]
# ### Load Data

# %% [markdown]
# SatCLIP embeddings

# %%
X = torch.load(str(parent / "s2100k-embeddings/satclip_embeddings.pt"))
X = X.numpy() # operations are on cpu

# %%
X
# Out:
# array([[-0.12198275, -0.10570826, -0.01822255, ..., -0.02585694,
#         -0.05298701,  0.00239364],
#        [-0.10403489,  0.01591932,  0.03106982, ...,  0.08658981,
#          0.0763995 ,  0.0314091 ],
#        [ 0.06508942, -0.01171703,  0.10875659, ..., -0.04767518,
#         -0.02129544,  0.00310934],
#        ...,
#        [-0.02103681,  0.13627657,  0.01789123, ...,  0.0284341 ,
#         -0.01903277, -0.01203714],
#        [-0.1209112 , -0.01841773,  0.00394719, ..., -0.05035377,
#         -0.11152306,  0.00350317],
#        [-0.1332136 , -0.08349636,  0.07614457, ...,  0.00073868,
#          0.01570184, -0.01015394]], shape=(69789, 256), dtype=float32)

# %% [markdown]
# Earth Engine Variables (from CSV with same indices as SatCLIP Embeddings)

# %%
df = pd.read_csv(str(parent/"text-descriptions/index_with_ee.csv"))

# %%
df
# Out:
#                     fn        lat         lon      avg_evi     avg_ndvi  \
# 0          patch_1.tif  24.517396   51.253355   749.956522   848.782609
# 1          patch_2.tif  42.969783  112.248149   992.913043  1298.173913
# 2          patch_3.tif -17.116714   19.013767  2899.130435  4440.217391
# 3          patch_5.tif  41.529312   23.845330  2439.173913  4137.739130
# 4          patch_7.tif  27.616751   26.800696   901.260870  1115.478261
# ...                ...        ...         ...          ...          ...
# 69784  patch_99995.tif  -1.128649  125.110689          NaN          NaN
# 69785  patch_99996.tif  80.721450   44.418605          NaN          NaN
# 69786  patch_99997.tif -73.608960   37.202655          NaN          NaN
# 69787  patch_99998.tif  31.619386   60.960150          NaN          NaN
# 69788  patch_99999.tif  17.142672   50.130782          NaN          NaN
#
#                                                    biome   country  \
# 0                             Deserts & Xeric Shrublands     Qatar
# 1                             Deserts & Xeric Shrublands     China
# 2      Tropical & Subtropical Grasslands, Savannas & ...    Angola
# 3                    Temperate Broadleaf & Mixed Forests  Bulgaria
# 4                             Deserts & Xeric Shrublands     Egypt
# ...                                                  ...       ...
# 69784                                                NaN       NaN
# 69785                                                NaN       NaN
# 69786                                                NaN       NaN
# 69787                                                NaN       NaN
# 69788                                                NaN       NaN
#
#                                        ecoregion  elevation_m  nightlights  \
# 0      Arabian-Persian Gulf coastal plain desert         22.0     0.445833
# 1                     Eastern Gobi desert steppe       1097.0     0.437500
# 2                   Zambezian Baikiaea woodlands       1157.0     0.249167
# 3                           Balkan mixed forests        469.0     0.455833
# 4                             East Sahara Desert        121.0     0.385833
# ...                                          ...          ...          ...
# 69784                                        NaN          NaN          NaN
# 69785                                        NaN          NaN          NaN
# 69786                                        NaN          NaN          NaN
# 69787                                        NaN          NaN          NaN
# 69788                                        NaN          NaN          NaN
#
#        ...       realm  soil_carbon_g_kg  soil_ph               state  \
# 0      ...  Palearctic               0.0      8.3   Jarayan Al Batnah
# 1      ...  Palearctic               0.0      8.1  Nei Mongol Zizhiqu
# 2      ...  Afrotropic               5.0      7.5      Cuando Cubango
# 3      ...  Palearctic              20.0      7.5         Blagoevgrad
# 4      ...  Palearctic               0.0      8.2          New Valley
# ...    ...         ...               ...      ...                 ...
# 69784  ...         NaN               NaN      NaN                 NaN
# 69785  ...         NaN               NaN      NaN                 NaN
# 69786  ...         NaN               NaN      NaN                 NaN
# 69787  ...         NaN               NaN      NaN                 NaN
# 69788  ...         NaN               NaN      NaN                 NaN
#
#        temp_annual_C temp_max_warmest_C  temp_min_coldest_C  temp_range_C  \
# 0          27.400000          41.500000           12.900000     28.600000
# 1           3.900000          28.799999          -23.299999     52.099998
# 2          22.200001          34.000000            6.300000     27.700001
# 3          12.000000          28.400000           -1.900000     30.299999
# 4          21.299999          37.500000            3.900000     33.599998
# ...              ...                ...                 ...           ...
# 69784            NaN                NaN                 NaN           NaN
# 69785            NaN                NaN                 NaN           NaN
# 69786            NaN                NaN                 NaN           NaN
# 69787            NaN                NaN                 NaN           NaN
# 69788            NaN                NaN                 NaN           NaN
#
#       tree_cover_pct              land_cover
# 0                0.0  Bare/Sparse Vegetation
# 1                0.0  Bare/Sparse Vegetation
# 2                3.0               Shrubland
# 3                7.0                Cropland
# 4                0.0  Bare/Sparse Vegetation
# ...              ...                     ...
# 69784            NaN                     NaN
# 69785            NaN                     NaN
# 69786            NaN                     NaN
# 69787            NaN                     NaN
# 69788            NaN                     NaN
#
# [69789 rows x 25 columns]

# %%
df.columns.to_numpy()
# Out:
# array(['fn', 'lat', 'lon', 'avg_evi', 'avg_ndvi', 'biome', 'country',
#        'ecoregion', 'elevation_m', 'nightlights', 'nnh', 'pop_density',
#        'precip_annual_mm', 'precip_driest_mm', 'precip_wettest_mm',
#        'realm', 'soil_carbon_g_kg', 'soil_ph', 'state', 'temp_annual_C',
#        'temp_max_warmest_C', 'temp_min_coldest_C', 'temp_range_C',
#        'tree_cover_pct', 'land_cover'], dtype=object)

# %% [markdown]
# Variable Processing from Dataframe

# %%
latlon_cols = ['lat', 'lon']

continuous_cols = [
    'avg_evi', 'avg_ndvi', 'elevation_m', 
    'nightlights', 'pop_density',
    'precip_annual_mm', 'precip_driest_mm', 'precip_wettest_mm',
    'soil_carbon_g_kg', 'soil_ph',
    'temp_annual_C', 'temp_max_warmest_C', 'temp_min_coldest_C',
    'temp_range_C', 'tree_cover_pct'
]

categorical_cols = ['biome', 'country', 'ecoregion', 'realm', 'state', 'land_cover', 'nnh']

drop_cols = ['fn']

# %%
print(df[continuous_cols].isnull().sum())
print(df[categorical_cols].isnull().sum())
# Out:
# avg_evi               11700
# avg_ndvi              11700
# elevation_m           11700
# nightlights           11700
# pop_density           11700
# precip_annual_mm      11700
# precip_driest_mm      11700
# precip_wettest_mm     11700
# soil_carbon_g_kg      11700
# soil_ph               11700
# temp_annual_C         11700
# temp_max_warmest_C    11700
# temp_min_coldest_C    11700
# temp_range_C          11700
# tree_cover_pct        11700
# dtype: int64
# biome         11724
# country       11700
# ecoregion     11700
# realm         11724
# state         11700
# land_cover    11700
# nnh           11724
# dtype: int64

# %% [markdown]
# Drop rows with missing columns

# %%
original_index = df.index

df = df.dropna(subset=continuous_cols)
df = df.dropna(subset=categorical_cols)

keep_idx = df.index

X = X[keep_idx]

# %%
df
# Out:
#                     fn        lat         lon      avg_evi     avg_ndvi  \
# 0          patch_1.tif  24.517396   51.253355   749.956522   848.782609
# 1          patch_2.tif  42.969783  112.248149   992.913043  1298.173913
# 2          patch_3.tif -17.116714   19.013767  2899.130435  4440.217391
# 3          patch_5.tif  41.529312   23.845330  2439.173913  4137.739130
# 4          patch_7.tif  27.616751   26.800696   901.260870  1115.478261
# ...                ...        ...         ...          ...          ...
# 69584  patch_99791.tif -28.881791  120.951277   863.086957  1757.260870
# 69585  patch_99792.tif -25.394124   22.642093  1567.826087  2737.782609
# 69586  patch_99795.tif  57.256255   96.340135  3176.260870  5863.913043
# 69587  patch_99796.tif  40.015116   94.781452   410.956522   590.956522
# 69588  patch_99797.tif  59.475110  -77.679048   701.478261  1922.173913
#
#                                                    biome    country  \
# 0                             Deserts & Xeric Shrublands      Qatar
# 1                             Deserts & Xeric Shrublands      China
# 2      Tropical & Subtropical Grasslands, Savannas & ...     Angola
# 3                    Temperate Broadleaf & Mixed Forests   Bulgaria
# 4                             Deserts & Xeric Shrublands      Egypt
# ...                                                  ...        ...
# 69584                         Deserts & Xeric Shrublands  Australia
# 69585                         Deserts & Xeric Shrublands   Botswana
# 69586                               Boreal Forests/Taiga     Russia
# 69587                         Deserts & Xeric Shrublands      China
# 69588                                             Tundra     Canada
#
#                                        ecoregion  elevation_m  nightlights  \
# 0      Arabian-Persian Gulf coastal plain desert         22.0     0.445833
# 1                     Eastern Gobi desert steppe       1097.0     0.437500
# 2                   Zambezian Baikiaea woodlands       1157.0     0.249167
# 3                           Balkan mixed forests        469.0     0.455833
# 4                             East Sahara Desert        121.0     0.385833
# ...                                          ...          ...          ...
# 69584        Western Australian Mulga shrublands        392.0     0.284167
# 69585                     Kalahari xeric savanna       1019.0     0.478333
# 69586                        East Siberian taiga        278.0     0.561667
# 69587                Alashan Plateau semi-desert       1550.0     0.458333
# 69588                 Canadian Low Arctic tundra         19.0     0.960833
#
#        ...        realm  soil_carbon_g_kg  soil_ph               state  \
# 0      ...   Palearctic               0.0      8.3   Jarayan Al Batnah
# 1      ...   Palearctic               0.0      8.1  Nei Mongol Zizhiqu
# 2      ...   Afrotropic               5.0      7.5      Cuando Cubango
# 3      ...   Palearctic              20.0      7.5         Blagoevgrad
# 4      ...   Palearctic               0.0      8.2          New Valley
# ...    ...          ...               ...      ...                 ...
# 69584  ...  Australasia               5.0      7.2   Western Australia
# 69585  ...   Afrotropic               5.0      7.1           Kgalagadi
# 69586  ...   Palearctic              95.0      5.2  Krasnoyarskiy Kray
# 69587  ...   Palearctic               0.0      7.9         Gansu Sheng
# 69588  ...     Nearctic             355.0      4.3     Quebec / Québec
#
#        temp_annual_C temp_max_warmest_C  temp_min_coldest_C  temp_range_C  \
# 0          27.400000          41.500000           12.900000     28.600000
# 1           3.900000          28.799999          -23.299999     52.099998
# 2          22.200001          34.000000            6.300000     27.700001
# 3          12.000000          28.400000           -1.900000     30.299999
# 4          21.299999          37.500000            3.900000     33.599998
# ...              ...                ...                 ...           ...
# 69584      20.000000          35.500000            5.700000     29.799999
# 69585      20.000000          34.400002            1.800000     32.599998
# 69586      -1.700000          24.600000          -27.799999     52.400002
# 69587       7.800000          30.500000          -16.500000     47.000000
# 69588      -7.100000          12.800000          -29.100000     41.900002
#
#       tree_cover_pct              land_cover
# 0                0.0  Bare/Sparse Vegetation
# 1                0.0  Bare/Sparse Vegetation
# 2                3.0               Shrubland
# 3                7.0                Cropland
# 4                0.0  Bare/Sparse Vegetation
# ...              ...                     ...
# 69584            2.0               Shrubland
# 69585            0.0               Shrubland
# 69586           56.0              Tree cover
# 69587            0.0  Bare/Sparse Vegetation
# 69588            6.0      Herbaceous wetland
#
# [58065 rows x 25 columns]

# %% [markdown]
# ### Some basic statistics

# %%
print(f"Means: \n\n{df[continuous_cols].mean()}")
print(f"\n\nMedians: \n\n{df[continuous_cols].median()}")
# Out:
# Means:
#
# avg_evi               1985.319101
# avg_ndvi              3300.522405
# elevation_m            710.579110
# nightlights              0.733771
# pop_density             46.949747
# precip_annual_mm       561.300353
# precip_driest_mm        11.267080
# precip_wettest_mm      106.992577
# soil_carbon_g_kg        22.485232
# soil_ph                  6.998033
# temp_annual_C           16.832700
# temp_max_warmest_C      32.620685
# temp_min_coldest_C       0.633648
# temp_range_C            31.987037
# tree_cover_pct          11.131973
# dtype: float64
#
#
# Medians:
#
# avg_evi               1642.739130
# avg_ndvi              2881.260870
# elevation_m            439.000000
# nightlights              0.386667
# pop_density              1.811839
# precip_annual_mm       398.000000
# precip_driest_mm         3.000000
# precip_wettest_mm       75.000000
# soil_carbon_g_kg        10.000000
# soil_ph                  7.400000
# temp_annual_C           20.000000
# temp_max_warmest_C      33.200001
# temp_min_coldest_C       4.500000
# temp_range_C            31.200001
# tree_cover_pct           2.000000
# dtype: float64

# %% [markdown]
# ### Continuous Variables
# (Focus on these for now)

# %% [markdown]
# Note: There are ways to implement this for categorical variables, but standard practice is doing a one-hot encoding. In practice, an issue arises when we have a high cardinality of categories (like country [185], state [2102], or even ecoregions [701] in our case). If we do this on enough samples (on the order of 70,000 which we have with S2-100k), we should be fine. However, we run into issues when we have fewer samples, where the resulting matrix has almost as many columns as observations, leading to overfitting. Other ways to combat this involve label encoding, and target encoding...

# %%
Y = df[continuous_cols].values
Y
# Out:
# array([[ 7.49956522e+02,  8.48782609e+02,  2.20000000e+01, ...,
#          1.28999996e+01,  2.86000004e+01,  0.00000000e+00],
#        [ 9.92913043e+02,  1.29817391e+03,  1.09700000e+03, ...,
#         -2.32999992e+01,  5.20999985e+01,  0.00000000e+00],
#        [ 2.89913043e+03,  4.44021739e+03,  1.15700000e+03, ...,
#          6.30000019e+00,  2.77000008e+01,  3.00000000e+00],
#        ...,
#        [ 3.17626087e+03,  5.86391304e+03,  2.78000000e+02, ...,
#         -2.77999992e+01,  5.24000015e+01,  5.60000000e+01],
#        [ 4.10956522e+02,  5.90956522e+02,  1.55000000e+03, ...,
#         -1.65000000e+01,  4.70000000e+01,  0.00000000e+00],
#        [ 7.01478261e+02,  1.92217391e+03,  1.90000000e+01, ...,
#         -2.91000004e+01,  4.19000015e+01,  6.00000000e+00]],
#       shape=(58065, 15))

# %% [markdown]
# #### Standardize

# %%
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()
scaler_Y = StandardScaler()

X_scaled = scaler_X.fit_transform(X)
Y_scaled = scaler_Y.fit_transform(Y)

# %% [markdown]
# ### CCA (Canonical Correlation Analysis)

# %%
from sklearn.cross_decomposition import CCA

# %%
n_components = min(15, Y.shape[1]) # just to try for now

cca = CCA(n_components=n_components)
X_c, Y_c = cca.fit_transform(X_scaled, Y_scaled)

# %%
corrs = [
    np.corrcoef(X_c[:, i], Y_c[:, i])[0, 1]
    for i in range(n_components)
]

for i, c in enumerate(corrs):
    print(f"Component {i+1}: {c:.3f}")
# Out:
# Component 1: 0.997
# Component 2: 0.971
# Component 3: 0.944
# Component 4: 0.907
# Component 5: 0.882
# Component 6: 0.851
# Component 7: 0.804
# Component 8: 0.767
# Component 9: 0.683
# Component 10: 0.635
# Component 11: 0.542
# Component 12: 0.504
# Component 13: 0.188
# Component 14: 0.145
# Component 15: 0.059

# %%
df_y_weights = pd.DataFrame(
    cca.y_weights_,
    index=continuous_cols,           # rows = variable names
    columns=[f"CC{i+1}" for i in range(cca.y_weights_.shape[1])]  # columns = components
)

df_y_weights_round = df_y_weights.round(3)
print(df_y_weights_round)
# Out:
#                       CC1    CC2    CC3    CC4    CC5    CC6    CC7    CC8  \
# avg_evi            -0.000  0.007 -0.020  0.178  0.049 -0.060 -0.114  0.251
# avg_ndvi            0.000 -0.009 -0.039  0.071 -0.239 -0.403 -0.602 -0.152
# elevation_m        -0.001  0.295  0.542  0.057 -0.003 -0.169  0.088  0.123
# nightlights         0.000 -0.001 -0.003  0.011  0.002 -0.029 -0.015  0.030
# pop_density         0.000 -0.000 -0.000  0.005 -0.003 -0.004 -0.026  0.010
# precip_annual_mm   -0.000  0.014 -0.123  0.826  0.113 -0.057 -0.040 -0.022
# precip_driest_mm    0.000 -0.012  0.025 -0.193  0.073 -0.781  0.127  0.409
# precip_wettest_mm   0.000  0.004  0.066 -0.383 -0.083  0.241 -0.560  0.092
# soil_carbon_g_kg    0.000 -0.011 -0.042 -0.048  0.093  0.291  0.103  0.688
# soil_ph            -0.000  0.006  0.095 -0.208 -0.158 -0.139  0.383 -0.448
# temp_annual_C      -0.002  0.938 -0.018 -0.008  0.049  0.062 -0.058 -0.038
# temp_max_warmest_C -0.381 -0.155  0.617  0.040  0.528  0.047 -0.165 -0.127
# temp_min_coldest_C  0.738 -0.089  0.490  0.137 -0.273  0.093 -0.014  0.056
# temp_range_C        0.557  0.016 -0.226 -0.154  0.723 -0.092 -0.095 -0.161
# tree_cover_pct     -0.000  0.004  0.031 -0.066  0.056  0.079  0.296 -0.039
#
#                       CC9   CC10   CC11   CC12   CC13   CC14   CC15
# avg_evi            -0.663 -0.112 -0.514 -0.405 -0.058 -0.047 -0.003
# avg_ndvi            0.344  0.247 -0.420  0.069 -0.116 -0.081 -0.090
# elevation_m         0.002 -0.335 -0.295  0.501  0.192  0.098  0.260
# nightlights        -0.004 -0.008 -0.056  0.001  0.105  0.858 -0.497
# pop_density        -0.043  0.030 -0.016  0.031  0.789 -0.377 -0.480
# precip_annual_mm   -0.203  0.260  0.246  0.338 -0.015  0.017  0.019
# precip_driest_mm   -0.108  0.093  0.356 -0.027 -0.080 -0.052 -0.084
# precip_wettest_mm  -0.469  0.124  0.275  0.386 -0.046  0.022 -0.000
# soil_carbon_g_kg    0.248  0.524 -0.247  0.099  0.051  0.026  0.094
# soil_ph            -0.309  0.609 -0.182  0.059  0.122  0.096  0.169
# temp_annual_C       0.029  0.152  0.120 -0.223 -0.081 -0.041 -0.111
# temp_max_warmest_C  0.066  0.205  0.075 -0.234 -0.074 -0.038 -0.100
# temp_min_coldest_C  0.025  0.105  0.149 -0.214 -0.085 -0.044 -0.115
# temp_range_C        0.012  0.000 -0.146  0.123  0.062  0.032  0.084
# tree_cover_pct     -0.069 -0.032 -0.220  0.369 -0.513 -0.290 -0.599

# %%
df_x_weights = pd.DataFrame(
    cca.x_weights_,
    index=[f"Embedding Component {i+1}" for i in range(256)],           # rows = variable names
    columns=[f"CC{i+1}" for i in range(cca.x_weights_.shape[1])]  # columns = components
)

df_x_weights_round = df_x_weights.round(3)
print(df_x_weights_round)
# Out:
#                            CC1    CC2    CC3    CC4    CC5    CC6    CC7  \
# Embedding Component 1    0.166 -0.147  0.084 -0.011  0.001 -0.085 -0.079
# Embedding Component 2    0.019  0.083  0.120  0.059  0.037 -0.039 -0.044
# Embedding Component 3   -0.118 -0.114  0.008  0.080 -0.034  0.001  0.107
# Embedding Component 4    0.058  0.006 -0.018  0.054  0.049  0.056  0.004
# Embedding Component 5    0.053  0.004 -0.019 -0.066  0.074  0.139  0.055
# ...                        ...    ...    ...    ...    ...    ...    ...
# Embedding Component 252  0.009  0.046  0.023  0.018  0.028  0.033 -0.059
# Embedding Component 253 -0.008  0.078  0.011 -0.010 -0.047  0.073 -0.016
# Embedding Component 254  0.026 -0.007 -0.028 -0.113 -0.009 -0.057 -0.081
# Embedding Component 255  0.035  0.045  0.018 -0.028 -0.051  0.056 -0.025
# Embedding Component 256 -0.053 -0.087 -0.003 -0.014  0.036 -0.052 -0.032
#
#                            CC8    CC9   CC10   CC11   CC12   CC13   CC14  \
# Embedding Component 1    0.043 -0.030 -0.003 -0.070  0.117 -0.063  0.016
# Embedding Component 2   -0.033 -0.008 -0.036 -0.015 -0.114  0.019  0.133
# Embedding Component 3    0.153  0.051 -0.026 -0.021  0.016  0.044 -0.024
# Embedding Component 4    0.026 -0.053 -0.027 -0.061 -0.125  0.064  0.134
# Embedding Component 5    0.015  0.142 -0.043  0.055 -0.012 -0.054  0.053
# ...                        ...    ...    ...    ...    ...    ...    ...
# Embedding Component 252 -0.063 -0.015  0.096  0.042 -0.030 -0.134  0.047
# Embedding Component 253  0.094  0.030  0.005  0.056 -0.037  0.062 -0.119
# Embedding Component 254 -0.042  0.034 -0.047 -0.075  0.005  0.031 -0.073
# Embedding Component 255  0.008  0.029  0.061 -0.007  0.040  0.099  0.036
# Embedding Component 256  0.008 -0.021 -0.061 -0.039  0.028 -0.037 -0.055
#
#                           CC15
# Embedding Component 1   -0.017
# Embedding Component 2    0.001
# Embedding Component 3   -0.113
# Embedding Component 4    0.006
# Embedding Component 5    0.046
# ...                        ...
# Embedding Component 252 -0.039
# Embedding Component 253  0.014
# Embedding Component 254  0.055
# Embedding Component 255 -0.007
# Embedding Component 256  0.014
#
# [256 rows x 15 columns]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

world = gpd.read_file("../../../data/shapefiles/ne_110m_admin_0_countries.shp")

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['lon'], df['lat']))

for i in range(3):
    fig, ax = plt.subplots(figsize=(14,6))
    world.boundary.plot(ax=ax, color='black', linewidth=1)
    gdf.plot(ax=ax, column=Y_c[:,i], cmap='coolwarm', markersize=15, legend=True,
             legend_kwds={'label': f'Embedding CC{i+1}', 'shrink': 0.6})
    ax.set_title(f'Spatial pattern of Environmental Variables on CC{i+1}', fontsize=16)
    ax.set_axis_off()
    plt.savefig(f"env_var_cc{i+1}.png")
    plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

world = gpd.read_file("../../../data/shapefiles/ne_110m_admin_0_countries.shp")

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['lon'], df['lat']))

for i in range(3):
    fig, ax = plt.subplots(figsize=(14,6))
    world.boundary.plot(ax=ax, color='black', linewidth=1)
    gdf.plot(ax=ax, column=X_c[:,i], cmap='viridis', markersize=15, legend=True,
             legend_kwds={'label': f'Embedding CC{i+1}', 'shrink': 0.6})
    ax.set_title(f'Spatial pattern of SatCLIP Embeddings on CC{i+1}', fontsize=16)
    ax.set_axis_off()
    plt.savefig(f"satclip_cc{i+1}.png")
    plt.show()
